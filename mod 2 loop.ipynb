# %%
# William R May
# Assignment 4.1
# This code assigns two numbers (secret and guess) and uses if/elif/else
# to check whether the guess is too low, too high, or just right.

secret = 7   # chosen number between 1 and 10
guess = 5    # another number between 1 and 10

if guess < secret:
    print("too low")
elif guess > secret:
    print("too high")
else:
    print("just right")

# William R May
# Assignment 4.2
# This code assigns boolean values to small and green,
# then uses if/else statements to determine which fruit/vegetable matches.

small = True
green = True

if small and red:
    print("cherry")
elif small and green:
    print("pea")
elif not small and green:
    print("watermelon")
else:
    print("pumpkin")
# William R May
# Assignment 6.1
# This code uses a for loop to print the values of the list [3, 2, 1, 0].

for value in [3, 2, 1, 0]:
    print(value)
# output
3
2
1
0

# William R May
# Assignment 6.2
# This code uses a while loop to compare number with guess_me.
# It prints 'too low' if number < guess_me,
# 'found it!' if number == guess_me, and 'oops' if number > guess_me.
# The loop increments number each time.

guess_me = 7
number = 1

while True:
    if number < guess_me:
        print("too low")
    elif number == guess_me:
        print("found it!")
        break
    else:  # number > guess_me
        print("oops")
        break
    number += 1
# output 
too low
too low
too low
too low
too low
too low
found it!

# William R May
# Assignment 6.3
# This code uses a for loop to iterate number over range(10).
# It prints 'too low' if number < guess_me,
# 'found it!' if number == guess_me (then breaks),
# and 'oops' if number > guess_me (then exits).

guess_me = 5

for number in range(10):
    if number < guess_me:
        print("too low")
    elif number == guess_me:
        print("found it!")
        break
    else:  # number > guess_me
        print("oops")
        break
# output
too low
too low
too low
too low
too low
found it!
